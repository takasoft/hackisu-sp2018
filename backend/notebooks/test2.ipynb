# %%
import scipy.io
data = scipy.io.loadmat('eeglab_data.set')
data = data['EEG']

# %%
data
# Out:
# array([[(array(['Continuous EEG Data'], dtype='<U19'), array(['eeglab_data.set'], dtype='<U15'), array(['/home/ftp/pub'], dtype='<U13'), array([[30504]], dtype=uint16), array([[32]], dtype=uint8), array([[1]], dtype=uint8), array([[128]], dtype=uint8), array([[0]], dtype=uint8), array([[238.3046875]]), array([[-35.797485  , -21.326353  , -26.28179   , ...,   3.2333739 ,
#           5.267354  ,  11.9899    ],
#        [  2.307844  ,  18.233702  ,  -1.5475922 , ...,   0.17153385,
#          -5.407942  ,  -4.441165  ],
#        [-26.776726  ,  -5.1745744 , -16.457743  , ...,  37.335007  ,
#          35.36798   ,  47.862335  ],
#        ...,
#        [-15.09065   ,  -2.3142467 ,  -6.388554  , ...,   7.3292212 ,
#           3.9009335 ,  12.517225  ],
#        [-20.528065  ,  -5.949618  , -12.331112  , ...,   7.942112  ,
#           1.5037638 ,   5.29876   ],
#        [ -9.50714   ,   7.3375797 ,   1.5345078 , ...,  17.725323  ,
# ...
